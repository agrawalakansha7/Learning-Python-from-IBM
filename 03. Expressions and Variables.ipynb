# %%
25+15+67 #addition
# Out:
# 107

# %%
78-65 #subtraction
# Out:
# 13

# %%
5*5 #multiplication
# Out:
# 25

# %%
25/5 #division
# Out:
# 5.0

# %%
23//7 #integer division
# Out:
# 3

# %%
#variables
x=6
y=7
z=x+y
z
# Out:
# 13
