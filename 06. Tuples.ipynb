# %%
tup = ("akku", 9, 8.45)
tup
# Out:
# ('akku', 9, 8.45)

# %%
type(tup)
# Out:
# tuple

# %%
# Print the variable on each index

print(tup[0])
print(tup[1])
print(tup[2])
# Out:
# akku
# 9
# 8.45

# %%
# Print the type of value on each index

print(type(tup[0]))
print(type(tup[1]))
print(type(tup[2]))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
# Use negative index to get the value of the last element

tup[-1]
# Out:
# 8.45

# %%
tup[-2]
# Out:
# 9

# %%
tup[-3]
# Out:
# 'akku'

# %%
# Concatenate two tuples

tup2 = tup + ("hard rock", 10)
tup2
# Out:
# ('akku', 9, 8.45, 'hard rock', 10)

# %%
# Slice from index 0 to index 2

tup2[0:3]
# Out:
# ('akku', 9, 8.45)

# %%
tup2[3:5]
# Out:
# ('hard rock', 10)

# %%
# get the length of tup2
len(tup2)
# Out:
# 5

# %%
#Sorting

# A sample tuple

A = (0, 9, 6, 5, 10, 8, 9, 6, 2)

# %%
A
# Out:
# (0, 9, 6, 5, 10, 8, 9, 6, 2)

# %%
A_Sorted= sorted(A)
A_Sorted
#output will be a new sorted list
# Out:
# [0, 2, 5, 6, 6, 8, 9, 9, 10]

# %%
# Nested Tuple

# Create a nest tuple

NestedT =(1, 2, ("pop", "rock") ,(3,4),("disco",(1,2)))
NestedT
# Out:
# (1, 2, ('pop', 'rock'), (3, 4), ('disco', (1, 2)))

# %%
# Print element on each index

print("Element 0 of Tuple: ", NestedT[0])
print("Element 1 of Tuple: ", NestedT[1])
print("Element 2 of Tuple: ", NestedT[2])
print("Element 3 of Tuple: ", NestedT[3])
print("Element 4 of Tuple: ", NestedT[4])
# Out:
# Element 0 of Tuple:  1
# Element 1 of Tuple:  2
# Element 2 of Tuple:  ('pop', 'rock')
# Element 3 of Tuple:  (3, 4)
# Element 4 of Tuple:  ('disco', (1, 2))

# %%
# Print element on each index, including nest indexes

print("Element 2, 0 of Tuple: ",   NestedT[2][0])
print("Element 2, 1 of Tuple: ",   NestedT[2][1])
print("Element 3, 0 of Tuple: ",   NestedT[3][0])
print("Element 3, 1 of Tuple: ",   NestedT[3][1])
print("Element 4, 0 of Tuple: ",   NestedT[4][0])
print("Element 4, 1 of Tuple: ",   NestedT[4][1])
# Out:
# Element 2, 0 of Tuple:  pop
# Element 2, 1 of Tuple:  rock
# Element 3, 0 of Tuple:  3
# Element 3, 1 of Tuple:  4
# Element 4, 0 of Tuple:  disco
# Element 4, 1 of Tuple:  (1, 2)

# %%
# Print the first character of the second element in the first nested tuple

NestedT[2][1][0]
# Out:
# 'r'

# %%
# Print the second character of the second element in the first nested tuple

NestedT[2][1][1]
# Out:
# 'o'

# %%
# Print the first element of the nested tuple inside the fifth element of the main tuple.

NestedT[4][1][0]
# Out:
# 1

# %%
# Print the second element of the nested tuple inside the fifth element of the main tuple.

NestedT[4][1][1]
# Out:
# 2

# %%
# Print the zeroth element of the nested tuple inside the fifth element of the main tuple.

NestedT[4][0]
# Out:
# 'disco'

# %%
# sample tuple

gen = ("pop", "rock", "soul", "hard rock", "soft rock", "R&B", "progressive rock", "disco") 
gen
# Out:
# ('pop',
#  'rock',
#  'soul',
#  'hard rock',
#  'soft rock',
#  'R&B',
#  'progressive rock',
#  'disco')

# %%
len(gen)
# Out:
# 8

# %%
#to find the index of s in "disco"

"disco".find("s")
# Out:
# 2

# %%
g = ("pop", "rock", "soul", "hard rock", "soft rock", "R&B", "progressive rock", "disco") 
g
# Out:
# ('pop',
#  'rock',
#  'soul',
#  'hard rock',
#  'soft rock',
#  'R&B',
#  'progressive rock',
#  'disco')

# %%
g.find("disco")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 g.find("disco")
#
# AttributeError: 'tuple' object has no attribute 'find'
